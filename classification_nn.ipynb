# %% [markdown]
# # ECE 285 Assignment 1: Classification using Neural Network
#
# Now that you have developed and tested your model on the toy dataset set. It's time to get down and get dirty with a standard dataset such as cifar10. At this point, you will be using the provided training data to tune the hyper-parameters of your network such that it works with cifar10 for the task of multi-class classification.
#
# Important: Recall that now we have non-linear decision boundaries, thus we do not need to do one vs all classification. We learn a single non-linear decision boundary instead. Our non-linear boundaries (thanks to relu non-linearity) will take care of differentiating between all the classes
#
# TO SUBMIT: PDF of this notebook with all the required outputs and answers.

# %%
# Prepare Packages
import numpy as np
import matplotlib.pyplot as plt

from ece285.utils.data_processing import get_cifar10_data
from ece285.utils.evaluation import get_classification_accuracy


# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # set default size of plots

# For auto-reloading external modules
# See http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# Use a subset of CIFAR10 for
# See http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# Use a subset of CIFAR10 for the assignment
dataset = get_cifar10_data(
    subset_train=5000,
    subset_val=250,
    subset_test=500,
)

print(dataset.keys())
print("Training Set Data  Shape: ", dataset["x_train"].shape)
print("Training Set Label Shape: ", dataset["y_train"].shape)
print("Validation Set Data  Shape: ", dataset["x_val"].shape)
print("Validation Set Label Shape: ", dataset["y_val"].shape)
print("Test Set Data  Shape: ", dataset["x_test"].shape)
print("Test Set Label Shape: ", dataset["y_test"].shape)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# dict_keys(['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test'])
# Training Set Data  Shape:  (5000, 3072)
# Training Set Label Shape:  (5000,)
# Validation Set Data  Shape:  (250, 3072)
# Validation Set Label Shape:  (250,)
# Test Set Data  Shape:  (500, 3072)
# Test Set Label Shape:  (500,)

# %%
x_train = dataset["x_train"]
y_train = dataset["y_train"]
x_val = dataset["x_val"]
y_val = dataset["y_val"]
x_test = dataset["x_test"]
y_test = dataset["y_test"]

# %%
# Import more utilies and the layers you have implemented
from ece285.layers.sequential import Sequential
from ece285.layers.linear import Linear
from ece285.layers.relu import ReLU
from ece285.layers.softmax import Softmax
from ece285.layers.loss_func import CrossEntropyLoss
from ece285.utils.optimizer import SGD
from ece285.utils.dataset import DataLoader
from ece285.utils.trainer import Trainer

# %% [markdown]
# ## Visualize some examples from the dataset.

# %%
# We show a few examples of training images from each class.
classes = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
]
samples_per_class = 7


def visualize_data(dataset, classes, samples_per_class):
    num_classes = len(classes)
    for y, cls in enumerate(classes):
        idxs = np.flatnonzero(y_train == y)
        idxs = np.random.choice(idxs, samples_per_class, replace=False)
        for i, idx in enumerate(idxs):
            plt_idx = i * num_classes + y + 1
            plt.subplot(samples_per_class, num_classes, plt_idx)
            plt.imshow(dataset[idx])
            plt.axis("off")
            if i == 0:
                plt.title(cls)
    plt.show()


# Visualize the first 10 classes
visualize_data(
    x_train.reshape(5000, 3, 32, 32).transpose(0, 2, 3, 1),
    classes,
    samples_per_class,
)

# %% [markdown]
# ## Initialize the model

# %%
input_size = 3072
hidden_size = 100  # Hidden layer size (Hyper-parameter)
num_classes = 10  # Output

# For a default setting we use the same model we used for the toy dataset.
# This tells you the power of a 2 layered Neural Network. Recall the Universal Approximation Theorem.
# A 2 layer neural network with non-linearities can approximate any function, given large enough hidden layer
def init_model():
    # np.random.seed(0) # No need to fix the seed here
    l1 = Linear(input_size, hidden_size)
    l2 = Linear(hidden_size, num_classes)

    r1 = ReLU()
    softmax = Softmax()
    return Sequential([l1, r1, l2, softmax])

# %%
# Initialize the dataset with the dataloader class
dataset = DataLoader(x_train, y_train, x_val, y_val, x_test, y_test)
net = init_model()
optim = SGD(net, lr=0.01, weight_decay=0.01)
loss_func = CrossEntropyLoss()
epoch = 200  # (Hyper-parameter)
batch_size = 200  # (Reduce the batch size if your computer is unable to handle it)

# %%
# Initialize the trainer class by passing the above modules
trainer = Trainer(
    dataset, optim, net, loss_func, epoch, batch_size, validate_interval=3
)

# %%
# Call the trainer function we have already implemented for you. This trains the model for the given
# hyper-parameters. It follows the same procedure as in the last ipython notebook you used for the toy-dataset
train_error, validation_accuracy = trainer.train()
# Out:
# Epoch Average Loss: 2.302580
# Validate Acc: 0.084
# Epoch Average Loss: 2.302562
# Epoch Average Loss: 2.302539
# Epoch Average Loss: 2.302506
# Validate Acc: 0.104
# Epoch Average Loss: 2.302453
# Epoch Average Loss: 2.302370
# Epoch Average Loss: 2.302234
# Validate Acc: 0.100
# Epoch Average Loss: 2.302008
# Epoch Average Loss: 2.301643
# Epoch Average Loss: 2.301040
# Validate Acc: 0.100
# Epoch Average Loss: 2.300099
# Epoch Average Loss: 2.298705
# Epoch Average Loss: 2.296871
# Validate Acc: 0.084
# Epoch Average Loss: 2.294905
# Epoch Average Loss: 2.293178
# Epoch Average Loss: 2.292018
# Validate Acc: 0.084
# Epoch Average Loss: 2.290743
# Epoch Average Loss: 2.289394
# Epoch Average Loss: 2.287654
# Validate Acc: 0.088
# Epoch Average Loss: 2.286797
# Epoch Average Loss: 2.287034
# Epoch Average Loss: 2.288234
# Validate Acc: 0.092
# Epoch Average Loss: 2.290713
# Epoch Average Loss: 2.291263
# Epoch Average Loss: 2.293752
# Validate Acc: 0.092
# Epoch Average Loss: 2.294214
# Epoch Average Loss: 2.298675
# Epoch Average Loss: 2.296543
# Validate Acc: 0.092
# Epoch Average Loss: 2.298957
# Epoch Average Loss: 2.300231
# Epoch Average Loss: 2.301043
# Validate Acc: 0.124
# Epoch Average Loss: 2.300483
# Epoch Average Loss: 2.301640
# Epoch Average Loss: 2.302103
# Validate Acc: 0.092
# Epoch Average Loss: 2.303014
# Epoch Average Loss: 2.308506
# Epoch Average Loss: 2.307586
# Validate Acc: 0.092
# Epoch Average Loss: 2.311856
# Epoch Average Loss: 2.311431
# Epoch Average Loss: 2.312105
# Validate Acc: 0.112
# Epoch Average Loss: 2.312105
# Epoch Average Loss: 2.313277
# Epoch Average Loss: 2.319814
# Validate Acc: 0.116
# Epoch Average Loss: 2.326949
# Epoch Average Loss: 2.328824
# Epoch Average Loss: 2.321550
# Validate Acc: 0.132
# Epoch Average Loss: 2.326447
# Epoch Average Loss: 2.326397
# Epoch Average Loss: 2.326309
# Validate Acc: 0.100
# Epoch Average Loss: 2.329908
# Epoch Average Loss: 2.328957
# Epoch Average Loss: 2.326411
# Validate Acc: 0.100
# Epoch Average Loss: 2.336331
# Epoch Average Loss: 2.333105
# Epoch Average Loss: 2.327322
# Validate Acc: 0.132
# Epoch Average Loss: 2.334300
# Epoch Average Loss: 2.330286
# Epoch Average Loss: 2.335695
# Validate Acc: 0.100
# Epoch Average Loss: 2.325888
# Epoch Average Loss: 2.327685
# Epoch Average Loss: 2.337190
# Validate Acc: 0.132
# Epoch Average Loss: 2.334765
# Epoch Average Loss: 2.333383
# Epoch Average Loss: 2.331689
# Validate Acc: 0.132
# Epoch Average Loss: 2.330433
# Epoch Average Loss: 2.327477
# Epoch Average Loss: 2.332485
# Validate Acc: 0.116
# Epoch Average Loss: 2.328932
# Epoch Average Loss: 2.334163
# Epoch Average Loss: 2.331964
# Validate Acc: 0.100
# Epoch Average Loss: 2.334487
# Epoch Average Loss: 2.336013
# Epoch Average Loss: 2.330516
# Validate Acc: 0.100
# Epoch Average Loss: 2.338401
# Epoch Average Loss: 2.329509
# Epoch Average Loss: 2.328653
# Validate Acc: 0.100
# Epoch Average Loss: 2.333552
# Epoch Average Loss: 2.331097
# Epoch Average Loss: 2.328065
# Validate Acc: 0.100
# Epoch Average Loss: 2.330816
# Epoch Average Loss: 2.332500
# Epoch Average Loss: 2.339228
# Validate Acc: 0.132
# Epoch Average Loss: 2.333195
# Epoch Average Loss: 2.329030
# Epoch Average Loss: 2.335326
# Validate Acc: 0.132
# Epoch Average Loss: 2.328230
# Epoch Average Loss: 2.333075
# Epoch Average Loss: 2.338746
# Validate Acc: 0.100
# Epoch Average Loss: 2.333620
# Epoch Average Loss: 2.336413
# Epoch Average Loss: 2.329156
# Validate Acc: 0.100
# Epoch Average Loss: 2.328950
# Epoch Average Loss: 2.326742
# Epoch Average Loss: 2.334034
# Validate Acc: 0.100
# Epoch Average Loss: 2.331707
# Epoch Average Loss: 2.336859
# Epoch Average Loss: 2.330357
# Validate Acc: 0.132
# Epoch Average Loss: 2.332398
# Epoch Average Loss: 2.334042
# Epoch Average Loss: 2.327923
# Validate Acc: 0.116
# Epoch Average Loss: 2.331679
# Epoch Average Loss: 2.330225
# Epoch Average Loss: 2.331099
# Validate Acc: 0.100
# Epoch Average Loss: 2.329045
# Epoch Average Loss: 2.331458
# Epoch Average Loss: 2.332987
# Validate Acc: 0.132
# Epoch Average Loss: 2.322670
# Epoch Average Loss: 2.328009
# Epoch Average Loss: 2.333118
# Validate Acc: 0.132
# Epoch Average Loss: 2.331482
# Epoch Average Loss: 2.330899
# Epoch Average Loss: 2.323617
# Validate Acc: 0.116
# Epoch Average Loss: 2.327661
# Epoch Average Loss: 2.328895
# Epoch Average Loss: 2.332799
# Validate Acc: 0.116
# Epoch Average Loss: 2.332344
# Epoch Average Loss: 2.331408
# Epoch Average Loss: 2.328768
# Validate Acc: 0.116
# Epoch Average Loss: 2.325269
# Epoch Average Loss: 2.333204
# Epoch Average Loss: 2.329904
# Validate Acc: 0.100
# Epoch Average Loss: 2.329895
# Epoch Average Loss: 2.334052
# Epoch Average Loss: 2.333258
# Validate Acc: 0.132
# Epoch Average Loss: 2.331282
# Epoch Average Loss: 2.330075
# Epoch Average Loss: 2.326266
# Validate Acc: 0.132
# Epoch Average Loss: 2.328343
# Epoch Average Loss: 2.333317
# Epoch Average Loss: 2.325916
# Validate Acc: 0.100
# Epoch Average Loss: 2.335982
# Epoch Average Loss: 2.326272
# Epoch Average Loss: 2.329884
# Validate Acc: 0.116
# Epoch Average Loss: 2.324801
# Epoch Average Loss: 2.340820
# Epoch Average Loss: 2.322151
# Validate Acc: 0.100
# Epoch Average Loss: 2.329677
# Epoch Average Loss: 2.329614
# Epoch Average Loss: 2.326209
# Validate Acc: 0.132
# Epoch Average Loss: 2.337175
# Epoch Average Loss: 2.325086
# Epoch Average Loss: 2.330132
# Validate Acc: 0.116
# Epoch Average Loss: 2.332548
# Epoch Average Loss: 2.330702
# Epoch Average Loss: 2.335710
# Validate Acc: 0.100
# Epoch Average Loss: 2.335367
# Epoch Average Loss: 2.326294
# Epoch Average Loss: 2.328586
# Validate Acc: 0.124
# Epoch Average Loss: 2.331878
# Epoch Average Loss: 2.330196
# Epoch Average Loss: 2.330377
# Validate Acc: 0.116
# Epoch Average Loss: 2.332740
# Epoch Average Loss: 2.338258
# Epoch Average Loss: 2.329325
# Validate Acc: 0.132
# Epoch Average Loss: 2.328127
# Epoch Average Loss: 2.325232
# Epoch Average Loss: 2.328341
# Validate Acc: 0.100
# Epoch Average Loss: 2.330949
# Epoch Average Loss: 2.329364
# Epoch Average Loss: 2.331213
# Validate Acc: 0.100
# Epoch Average Loss: 2.326500
# Epoch Average Loss: 2.331134
# Epoch Average Loss: 2.329062
# Validate Acc: 0.100
# Epoch Average Loss: 2.334712
# Epoch Average Loss: 2.329101
# Epoch Average Loss: 2.333910
# Validate Acc: 0.132
# Epoch Average Loss: 2.330355
# Epoch Average Loss: 2.321853
# Epoch Average Loss: 2.332531
# Validate Acc: 0.132
# Epoch Average Loss: 2.326613
# Epoch Average Loss: 2.327945
# Epoch Average Loss: 2.332875
# Validate Acc: 0.116
# Epoch Average Loss: 2.328321
# Epoch Average Loss: 2.332094
# Epoch Average Loss: 2.330109
# Validate Acc: 0.132
# Epoch Average Loss: 2.321091
# Epoch Average Loss: 2.330577
# Epoch Average Loss: 2.333143
# Validate Acc: 0.100
# Epoch Average Loss: 2.332318
# Epoch Average Loss: 2.330284
# Epoch Average Loss: 2.327159
# Validate Acc: 0.132
# Epoch Average Loss: 2.334100
# Epoch Average Loss: 2.324447
# Epoch Average Loss: 2.334523
# Validate Acc: 0.100
# Epoch Average Loss: 2.325365
# Epoch Average Loss: 2.334258
# Epoch Average Loss: 2.325737
# Validate Acc: 0.100
# Epoch Average Loss: 2.328654
# Epoch Average Loss: 2.324784
# Epoch Average Loss: 2.335451
# Validate Acc: 0.100
# Epoch Average Loss: 2.328399
# Epoch Average Loss: 2.334948
# Epoch Average Loss: 2.332947
# Validate Acc: 0.116
# Epoch Average Loss: 2.325935
# Epoch Average Loss: 2.331094
# Epoch Average Loss: 2.330225
# Validate Acc: 0.100
# Epoch Average Loss: 2.331569
# Epoch Average Loss: 2.321928
# Epoch Average Loss: 2.329123
# Validate Acc: 0.100
# Epoch Average Loss: 2.326542

# %% [markdown]
# ### Print the training and validation accuracies for the default hyper-parameters provided

# %%
from ece285.utils.evaluation import get_classification_accuracy

out_train = net.predict(x_train)
acc = get_classification_accuracy(out_train, y_train)
print("Training acc: ", acc)
out_val = net.predict(x_val)
acc = get_classification_accuracy(out_val, y_val)
print("Validation acc: ", acc)
# Out:
# Training acc:  0.1266
# Validation acc:  0.132

# %% [markdown]
# ### Debug the training
# With the default parameters we provided above, you should get a validation accuracy of around ~0.2 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the training loss function and the validation accuracies during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the training loss function and validation accuracies
plt.subplot(2, 1, 1)
plt.plot(train_error)
plt.title("Training Loss History")
plt.xlabel("Iteration")
plt.ylabel("Loss")

plt.subplot(2, 1, 2)
# plt.plot(stats['train_acc_history'], label='train')
plt.plot(validation_accuracy, label="val")
plt.title("Classification accuracy history")
plt.xlabel("Epoch")
plt.ylabel("Classification accuracy")
plt.legend()
plt.show()

# %%
from ece285.utils.vis_utils import visualize_grid

# Credits: http://cs231n.stanford.edu/

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net._modules[0].parameters[0]
    W1 = W1.reshape(3, 32, 32, -1).transpose(3, 1, 2, 0)
    plt.imshow(visualize_grid(W1, padding=3).astype("uint8"))
    plt.gca().axis("off")
    plt.show()


show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters (50%)
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 40% on the validation set. Our best network gets over 40% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on cifar10 as you can (40% could serve as a reference), with a fully-connected Neural Network.

# %% [markdown]
# #### Explain your hyperparameter tuning process below.
#
# #### Your Answer:

# %%
best_net_hyperparams = None  # store the best model into this

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model hyperparams in best_net.                                                #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# You are now free to test different combinations of hyperparameters to build   #
# various models and test them according to the above plots and visualization   #


# TODO: Show the above plots and visualizations for the default params (already #
# done) and the best hyper-params you obtain. You only need to show this for 2  #
# sets of hyper-params.                                                         #
# You just need to store values for the hyperparameters in best_net_hyperparams #
# as a list in the order
# best_net_hyperparams = [lr, weight_decay, epoch, hidden_size]
#################################################################################

optim = SGD(net, lr=2e-3, weight_decay = 0.01)
epoch = 1000
trainer = Trainer(dataset, optim, net, loss_func, epoch, batch_size, validate_interval=3)
train_error, validation_accuracy = trainer.train()

val_acc = (net.predict(x_val) == y_val).mean()
print("Validation accuracy: ", val_acc)

best_net_hyperparams = net
# Out:
# Average Loss: 2.333751
# Epoch Average Loss: 2.331898
# Validate Acc: 0.100
# Epoch Average Loss: 2.326451
# Epoch Average Loss: 2.324245
# Epoch Average Loss: 2.326695
# Validate Acc: 0.100
# Epoch Average Loss: 2.325845
# Epoch Average Loss: 2.322705
# Epoch Average Loss: 2.329827
# Validate Acc: 0.116
# Epoch Average Loss: 2.324677
# Epoch Average Loss: 2.328123
# Epoch Average Loss: 2.328156
# Validate Acc: 0.132
# Epoch Average Loss: 2.327462
# Epoch Average Loss: 2.325412
# Epoch Average Loss: 2.332525
# Validate Acc: 0.100
# Epoch Average Loss: 2.324321
# Epoch Average Loss: 2.323670
# Epoch Average Loss: 2.327360
# Validate Acc: 0.100
# Epoch Average Loss: 2.331355
# Epoch Average Loss: 2.324603
# Epoch Average Loss: 2.325364
# Validate Acc: 0.132
# Epoch Average Loss: 2.329701
# Epoch Average Loss: 2.329070
# Epoch Average Loss: 2.322934
# Validate Acc: 0.132
# Epoch Average Loss: 2.330603
# Epoch Average Loss: 2.333678
# Epoch Average Loss: 2.331090
# Validate Acc: 0.116
# Epoch Average Loss: 2.327608
# Epoch Average Loss: 2.326461
# Epoch Average Loss: 2.332973
# Validate Acc: 0.116
# Epoch Average Loss: 2.329263
# Epoch Average Loss: 2.323316
# Epoch Average Loss: 2.325307
# Validate Acc: 0.100
# Epoch Average Loss: 2.328243
# Epoch Average Loss: 2.322645
# Epoch Average Loss: 2.326701
# Validate Acc: 0.116
# Epoch Average Loss: 2.327220
# Epoch Average Loss: 2.323430
# Epoch Average Loss: 2.326196
# Validate Acc: 0.116
# Epoch Average Loss: 2.326555
# Epoch Average Loss: 2.329200
# Epoch Average Loss: 2.324215
# Validate Acc: 0.116
# Epoch Average Loss: 2.324075
# Epoch Average Loss: 2.329074
# Epoch Average Loss: 2.336568
# Validate Acc: 0.100
# Epoch Average Loss: 2.327958
# Epoch Average Loss: 2.330632
# Epoch Average Loss: 2.330816
# Validate Acc: 0.132
# Epoch Average Loss: 2.326923
# Epoch Average Loss: 2.323525
# Epoch Average Loss: 2.326598
# Validate Acc: 0.100
# Epoch Average Loss: 2.319187
# Epoch Average Loss: 2.327865
# Epoch Average Loss: 2.332807
# Validate Acc: 0.132
# Epoch Average Loss: 2.323291
# Epoch Average Loss: 2.323220
# Epoch Average Loss: 2.327657
# Validate Acc: 0.100
# Epoch Average Loss: 2.330907
# Epoch Average Loss: 2.328355
# Epoch Average Loss: 2.330938
# Validate Acc: 0.132
# Epoch Average Loss: 2.331895
# Epoch Average Loss: 2.324902
# Epoch Average Loss: 2.330501
# Validate Acc: 0.132
# Epoch Average Loss: 2.324788
# Epoch Average Loss: 2.329375
# Epoch Average Loss: 2.333314
# Validate Acc: 0.132
# Epoch Average Loss: 2.324287
# Epoch Average Loss: 2.326065
# Epoch Average Loss: 2.327436
# Validate Acc: 0.100
# Epoch Average Loss: 2.328927
# Epoch Average Loss: 2.327683
# Epoch Average Loss: 2.322230
# Validate Acc: 0.100
# Epoch Average Loss: 2.328885
# Epoch Average Loss: 2.321932
# Epoch Average Loss: 2.323471
# Validate Acc: 0.132
# Epoch Average Loss: 2.331569
# Epoch Average Loss: 2.330746
# Epoch Average Loss: 2.328018
# Validate Acc: 0.100
# Epoch Average Loss: 2.329081
# Epoch Average Loss: 2.326785
# Epoch Average Loss: 2.323613
# Validate Acc: 0.116
# Epoch Average Loss: 2.329846
# Epoch Average Loss: 2.329415
# Epoch Average Loss: 2.323848
# Validate Acc: 0.132
# Epoch Average Loss: 2.329896
# Epoch Average Loss: 2.328932
# Epoch Average Loss: 2.324535
# Validate Acc: 0.100
# Epoch Average Loss: 2.326429
# Epoch Average Loss: 2.329960
# Epoch Average Loss: 2.330927
# Validate Acc: 0.132
# Epoch Average Loss: 2.331607
# Epoch Average Loss: 2.328865
# Epoch Average Loss: 2.335748
# Validate Acc: 0.132
# Epoch Average Loss: 2.324746
# Epoch Average Loss: 2.324732
# Epoch Average Loss: 2.325914
# Validate Acc: 0.132
# Epoch Average Loss: 2.327116
# Epoch Average Loss: 2.332189
# Epoch Average Loss: 2.329506
# Validate Acc: 0.116
# Epoch Average Loss: 2.319870
# Epoch Average Loss: 2.329174
# Epoch Average Loss: 2.331183
# Validate Acc: 0.132
# Epoch Average Loss: 2.328600
# Epoch Average Loss: 2.333111
# Epoch Average Loss: 2.325962
# Validate Acc: 0.100
# Epoch Average Loss: 2.333509
# Epoch Average Loss: 2.327493
# Epoch Average Loss: 2.323278
# Validate Acc: 0.100
# Epoch Average Loss: 2.323855
# Epoch Average Loss: 2.325862
# Epoch Average Loss: 2.324415
# Validate Acc: 0.100
# Epoch Average Loss: 2.331456
# Epoch Average Loss: 2.327927
# Epoch Average Loss: 2.332536
# Validate Acc: 0.100
# Epoch Average Loss: 2.331048
# Epoch Average Loss: 2.327043
# Epoch Average Loss: 2.323582
# Validate Acc: 0.116
# Epoch Average Loss: 2.333163
# Epoch Average Loss: 2.327345
# Epoch Average Loss: 2.326608
# Validate Acc: 0.100
# Epoch Average Loss: 2.323411
# Epoch Average Loss: 2.330287
# Epoch Average Loss: 2.322418
# Validate Acc: 0.100
# Epoch Average Loss: 2.323052
# Epoch Average Loss: 2.325357
# Epoch Average Loss: 2.329151
# Validate Acc: 0.100
# Epoch Average Loss: 2.321768
# Epoch Average Loss: 2.329782
# Epoch Average Loss: 2.324971
# Validate Acc: 0.116
# Epoch Average Loss: 2.330002
# Epoch Average Loss: 2.327643
# Epoch Average Loss: 2.327946
# Validate Acc: 0.116
# Epoch Average Loss: 2.332870
# Epoch Average Loss: 2.330175
# Epoch Average Loss: 2.331574
# Validate Acc: 0.100
# Epoch Average Loss: 2.327730
# Epoch Average Loss: 2.326353
# Epoch Average Loss: 2.326068
# Validate Acc: 0.100
# Epoch Average Loss: 2.328321
# Epoch Average Loss: 2.326067
# Epoch Average Loss: 2.329462
# Validate Acc: 0.100
# Epoch Average Loss: 2.332808
# Epoch Average Loss: 2.329001
# Epoch Average Loss: 2.322791
# Validate Acc: 0.132
# Epoch Average Loss: 2.328011
# Epoch Average Loss: 2.326685
# Epoch Average Loss: 2.324430
# Validate Acc: 0.116
# Epoch Average Loss: 2.317779
# Epoch Average Loss: 2.327006
# Epoch Average Loss: 2.323685
# Validate Acc: 0.116
# Epoch Average Loss: 2.326883
# Epoch Average Loss: 2.329971
# Epoch Average Loss: 2.332634
# Validate Acc: 0.100
# Epoch Average Loss: 2.332023
# Epoch Average Loss: 2.333919
# Epoch Average Loss: 2.323804
# Validate Acc: 0.132
# Epoch Average Loss: 2.330001
# Epoch Average Loss: 2.320569
# Epoch Average Loss: 2.321731
# Validate Acc: 0.132
# Epoch Average Loss: 2.330569
# Epoch Average Loss: 2.334105
# Epoch Average Loss: 2.324000
# Validate Acc: 0.100
# Epoch Average Loss: 2.324633
# Epoch Average Loss: 2.328917
# Epoch Average Loss: 2.328143
# Validate Acc: 0.132
# Epoch Average Loss: 2.334878
# Epoch Average Loss: 2.333137
# Epoch Average Loss: 2.336697
# Validate Acc: 0.100
# Epoch Average Loss: 2.333210
# Epoch Average Loss: 2.326333
# Epoch Average Loss: 2.320572
# Validate Acc: 0.100
# Epoch Average Loss: 2.324245
# Epoch Average Loss: 2.323904
# Epoch Average Loss: 2.332482
# Validate Acc: 0.132
# Epoch Average Loss: 2.324849
# Epoch Average Loss: 2.332439
# Epoch Average Loss: 2.330442
# Validate Acc: 0.132
# Epoch Average Loss: 2.332080
# Epoch Average Loss: 2.332267
# Epoch Average Loss: 2.330135
# Validate Acc: 0.116
# Epoch Average Loss: 2.328522
# Epoch Average Loss: 2.328551
# Epoch Average Loss: 2.325603
# Validate Acc: 0.100
# Epoch Average Loss: 2.326967
# Epoch Average Loss: 2.320811
# Epoch Average Loss: 2.320896
# Validate Acc: 0.100
# Epoch Average Loss: 2.326229
# Epoch Average Loss: 2.321505
# Epoch Average Loss: 2.329038
# Validate Acc: 0.100
# Epoch Average Loss: 2.327465
# Epoch Average Loss: 2.328792
# Epoch Average Loss: 2.326764
# Validate Acc: 0.132
# Epoch Average Loss: 2.331830
# Epoch Average Loss: 2.323051
# Epoch Average Loss: 2.325517
# Validate Acc: 0.116
# Epoch Average Loss: 2.324439
# Epoch Average Loss: 2.329386
# Epoch Average Loss: 2.328256
# Validate Acc: 0.132
# Epoch Average Loss: 2.322817
# Epoch Average Loss: 2.323186
# Epoch Average Loss: 2.328054
# Validate Acc: 0.116
# Epoch Average Loss: 2.325676
# Epoch Average Loss: 2.327867
# Epoch Average Loss: 2.332736
# Validate Acc: 0.132
# Epoch Average Loss: 2.337401
# Epoch Average Loss: 2.329204
# Epoch Average Loss: 2.324725
# Validate Acc: 0.132
# Epoch Average Loss: 2.320532
# Epoch Average Loss: 2.325166
# Epoch Average Loss: 2.322701
# Validate Acc: 0.132
# Epoch Average Loss: 2.335842
# Epoch Average Loss: 2.322664
# Epoch Average Loss: 2.330532
# Validate Acc: 0.132
# Epoch Average Loss: 2.324343
# Epoch Average Loss: 2.325952
# Epoch Average Loss: 2.323531
# Validate Acc: 0.100
# Epoch Average Loss: 2.330979
# Epoch Average Loss: 2.328989
# Epoch Average Loss: 2.332263
# Validate Acc: 0.100
# Epoch Average Loss: 2.331799
# Epoch Average Loss: 2.329626
# Epoch Average Loss: 2.324998
# Validate Acc: 0.132
# Epoch Average Loss: 2.323545
# Epoch Average Loss: 2.332153
# Epoch Average Loss: 2.327619
# Validate Acc: 0.100
# Epoch Average Loss: 2.326718
# Epoch Average Loss: 2.331536
# Epoch Average Loss: 2.322089
# Validate Acc: 0.116
# Epoch Average Loss: 2.321955
# Epoch Average Loss: 2.332528
# Epoch Average Loss: 2.328321
# Validate Acc: 0.132
# Epoch Average Loss: 2.323397
# Epoch Average Loss: 2.327819
# Epoch Average Loss: 2.326462
# Validate Acc: 0.132
# Epoch Average Loss: 2.321777
# Epoch Average Loss: 2.332157
# Epoch Average Loss: 2.333588
# Validate Acc: 0.132
# Epoch Average Loss: 2.325809
# Epoch Average Loss: 2.331347
# Epoch Average Loss: 2.323904
# Validate Acc: 0.100
# Epoch Average Loss: 2.324014
# Epoch Average Loss: 2.331880
# Epoch Average Loss: 2.326015
# Validate Acc: 0.100
# Epoch Average Loss: 2.327058
# Epoch Average Loss: 2.323532
# Epoch Average Loss: 2.322574
# Validate Acc: 0.132
# Epoch Average Loss: 2.330865
# Epoch Average Loss: 2.328391
# Epoch Average Loss: 2.328431
# Validate Acc: 0.100
# Epoch Average Loss: 2.328081
# Epoch Average Loss: 2.328081
# Epoch Average Loss: 2.325176
# Validate Acc: 0.100
# Epoch Average Loss: 2.322554
# Epoch Average Loss: 2.328819
# Epoch Average Loss: 2.329657
# Validate Acc: 0.132
# Epoch Average Loss: 2.328859
# Epoch Average Loss: 2.323944
# Epoch Average Loss: 2.327510
# Validate Acc: 0.116
# Epoch Average Loss: 2.324043
# Epoch Average Loss: 2.328723
# Epoch Average Loss: 2.327603
# Validate Acc: 0.132
# Epoch Average Loss: 2.331943
# Epoch Average Loss: 2.334505
# Epoch Average Loss: 2.331004
# Validate Acc: 0.100
# Epoch Average Loss: 2.321393
# Epoch Average Loss: 2.323980
# Epoch Average Loss: 2.328848
# Validate Acc: 0.132
# Epoch Average Loss: 2.323721
# Epoch Average Loss: 2.335639
# Epoch Average Loss: 2.326402
# Validate Acc: 0.132
# Epoch Average Loss: 2.322563
# Epoch Average Loss: 2.332370
# Epoch Average Loss: 2.332091
# Validate Acc: 0.132
# Epoch Average Loss: 2.327817
# Epoch Average Loss: 2.328331
# Epoch Average Loss: 2.323661
# Validate Acc: 0.132
# Epoch Average Loss: 2.326658
# Epoch Average Loss: 2.327802
# Epoch Average Loss: 2.334890
# Validate Acc: 0.132
# Epoch Average Loss: 2.330783
# Epoch Average Loss: 2.324489
# Epoch Average Loss: 2.330339
# Validate Acc: 0.132
# Epoch Average Loss: 2.332562
# Epoch Average Loss: 2.326175
# Epoch Average Loss: 2.326276
# Validate Acc: 0.100
# Epoch Average Loss: 2.330992
# Epoch Average Loss: 2.332440
# Epoch Average Loss: 2.330574
# Validate Acc: 0.100
# Epoch Average Loss: 2.327214
# Epoch Average Loss: 2.323666
# Epoch Average Loss: 2.323374
# Validate Acc: 0.100
# Epoch Average Loss: 2.328370
# Epoch Average Loss: 2.330469
# Epoch Average Loss: 2.328969
# Validate Acc: 0.100
# Epoch Average Loss: 2.319663
# Epoch Average Loss: 2.332120
# Epoch Average Loss: 2.320189
# Validate Acc: 0.116
# Epoch Average Loss: 2.324083
# Epoch Average Loss: 2.325797
# Epoch Average Loss: 2.329108
# Validate Acc: 0.132
# Epoch Average Loss: 2.323976
# Epoch Average Loss: 2.327518
# Epoch Average Loss: 2.334237
# Validate Acc: 0.116
# Epoch Average Loss: 2.327368
# Epoch Average Loss: 2.330252
# Epoch Average Loss: 2.330253
# Validate Acc: 0.100
# Epoch Average Loss: 2.329946
# Epoch Average Loss: 2.325729
# Epoch Average Loss: 2.327081
# Validate Acc: 0.132
# Epoch Average Loss: 2.332021
# Epoch Average Loss: 2.324708
# Epoch Average Loss: 2.333775
# Validate Acc: 0.132
# Epoch Average Loss: 2.324240
# Epoch Average Loss: 2.325985
# Epoch Average Loss: 2.328908
# Validate Acc: 0.100
# Epoch Average Loss: 2.331070
# Epoch Average Loss: 2.331503
# Epoch Average Loss: 2.322560
# Validate Acc: 0.100
# Epoch Average Loss: 2.329596
# Epoch Average Loss: 2.329073
# Epoch Average Loss: 2.325604
# Validate Acc: 0.100
# Epoch Average Loss: 2.322616
# Epoch Average Loss: 2.327807
# Epoch Average Loss: 2.331530
# Validate Acc: 0.116
# Epoch Average Loss: 2.329354
# Epoch Average Loss: 2.326885
# Epoch Average Loss: 2.326234
# Validate Acc: 0.132
# Epoch Average Loss: 2.328479
# Epoch Average Loss: 2.326714
# Epoch Average Loss: 2.331347
# Validate Acc: 0.132
# Epoch Average Loss: 2.324581
# Epoch Average Loss: 2.327330
# Epoch Average Loss: 2.330208
# Validate Acc: 0.116
# Epoch Average Loss: 2.330263
# Epoch Average Loss: 2.326699
# Epoch Average Loss: 2.328070
# Validate Acc: 0.132
# Epoch Average Loss: 2.320345
# Epoch Average Loss: 2.326062
# Epoch Average Loss: 2.325968
# Validate Acc: 0.132
# Epoch Average Loss: 2.327225
# Epoch Average Loss: 2.326610
# Epoch Average Loss: 2.331956
# Validate Acc: 0.100
# Epoch Average Loss: 2.328723
# Epoch Average Loss: 2.324438
# Epoch Average Loss: 2.336315
# Validate Acc: 0.100
# Epoch Average Loss: 2.323831
# Epoch Average Loss: 2.333245
# Epoch Average Loss: 2.323511
# Validate Acc: 0.100
# Epoch Average Loss: 2.326198
# Epoch Average Loss: 2.328612
# Epoch Average Loss: 2.325416
# Validate Acc: 0.100
# Epoch Average Loss: 2.329419
# Epoch Average Loss: 2.326197
# Epoch Average Loss: 2.319110
# Validate Acc: 0.100
# Epoch Average Loss: 2.322646
# Epoch Average Loss: 2.329828
# Epoch Average Loss: 2.325277
# Validate Acc: 0.116
# Epoch Average Loss: 2.328137
# Epoch Average Loss: 2.327359
# Epoch Average Loss: 2.326514
# Validate Acc: 0.116
# Epoch Average Loss: 2.326933
# Epoch Average Loss: 2.332603
# Epoch Average Loss: 2.329947
# Validate Acc: 0.116
# Epoch Average Loss: 2.328920
# Epoch Average Loss: 2.319846
# Epoch Average Loss: 2.327514
# Validate Acc: 0.132
# Epoch Average Loss: 2.326945
# Epoch Average Loss: 2.325352
# Epoch Average Loss: 2.328390
# Validate Acc: 0.100
# Epoch Average Loss: 2.327752
# Epoch Average Loss: 2.322539
# Epoch Average Loss: 2.324541
# Validate Acc: 0.100
# Epoch Average Loss: 2.326479
# Epoch Average Loss: 2.336023
# Epoch Average Loss: 2.326891
# Validate Acc: 0.100
# Epoch Average Loss: 2.325807
# Epoch Average Loss: 2.328181
# Epoch Average Loss: 2.327311
# Validate Acc: 0.132
# Epoch Average Loss: 2.327365
# Epoch Average Loss: 2.331633
# Epoch Average Loss: 2.330052
# Validate Acc: 0.132
# Epoch Average Loss: 2.328957
# Epoch Average Loss: 2.328576
# Epoch Average Loss: 2.327828
# Validate Acc: 0.132
# Epoch Average Loss: 2.321745
# Epoch Average Loss: 2.334057
# Epoch Average Loss: 2.331368
# Validate Acc: 0.116
# Epoch Average Loss: 2.327090
# Epoch Average Loss: 2.328830
# Epoch Average Loss: 2.322492
# Validate Acc: 0.116
# Epoch Average Loss: 2.325003
# Epoch Average Loss: 2.323852
# Epoch Average Loss: 2.323594
# Validate Acc: 0.132
# Epoch Average Loss: 2.327022
# Epoch Average Loss: 2.325756
# Epoch Average Loss: 2.320690
# Validate Acc: 0.100
# Epoch Average Loss: 2.328286
# Epoch Average Loss: 2.327563
# Epoch Average Loss: 2.324224
# Validate Acc: 0.132
# Epoch Average Loss: 2.325260
# Epoch Average Loss: 2.321097
# Epoch Average Loss: 2.328388
# Validate Acc: 0.100
# Epoch Average Loss: 2.322880
# Epoch Average Loss: 2.330459
# Epoch Average Loss: 2.328546
# Validate Acc: 0.100
# Epoch Average Loss: 2.328102
# Epoch Average Loss: 2.329575
# Epoch Average Loss: 2.324978
# Validate Acc: 0.100
# Epoch Average Loss: 2.325422
# Epoch Average Loss: 2.331867
# Epoch Average Loss: 2.329483
# Validate Acc: 0.116
# Epoch Average Loss: 2.331408
# Epoch Average Loss: 2.327918
# Epoch Average Loss: 2.319440
# Validate Acc: 0.132
# Epoch Average Loss: 2.322895
# Epoch Average Loss: 2.330536
# Epoch Average Loss: 2.321215
# Validate Acc: 0.132
# Epoch Average Loss: 2.325273
# Epoch Average Loss: 2.329338
# Epoch Average Loss: 2.325853
# Validate Acc: 0.116
# Epoch Average Loss: 2.330147
# Epoch Average Loss: 2.326464
# Epoch Average Loss: 2.324540
# Validate Acc: 0.132
# Epoch Average Loss: 2.325450
# Epoch Average Loss: 2.328106
# Epoch Average Loss: 2.324342
# Validate Acc: 0.100
# Epoch Average Loss: 2.330301
# Epoch Average Loss: 2.330484
# Epoch Average Loss: 2.328578
# Validate Acc: 0.116
# Epoch Average Loss: 2.333753
# Epoch Average Loss: 2.331982
# Epoch Average Loss: 2.325695
# Validate Acc: 0.100
# Epoch Average Loss: 2.326497
# Epoch Average Loss: 2.330039
# Epoch Average Loss: 2.324446
# Validate Acc: 0.100
# Epoch Average Loss: 2.330041
# Epoch Average Loss: 2.335885
# Epoch Average Loss: 2.327829
# Validate Acc: 0.116
# Epoch Average Loss: 2.324196
# Epoch Average Loss: 2.328611
# Epoch Average Loss: 2.326814
# Validate Acc: 0.132
# Epoch Average Loss: 2.324946
# Epoch Average Loss: 2.325554
# Epoch Average Loss: 2.326579
# Validate Acc: 0.100
# Epoch Average Loss: 2.324654
# Epoch Average Loss: 2.329665
# Epoch Average Loss: 2.325301
# Validate Acc: 0.100
# Epoch Average Loss: 2.325589
# Epoch Average Loss: 2.326202
# Epoch Average Loss: 2.328745
# Validate Acc: 0.100
# Epoch Average Loss: 2.328298
# Epoch Average Loss: 2.324738
# Epoch Average Loss: 2.327659
# Validate Acc: 0.132
# Epoch Average Loss: 2.329184
# Epoch Average Loss: 2.326763
# Epoch Average Loss: 2.320373
# Validate Acc: 0.116
# Epoch Average Loss: 2.322501
# Epoch Average Loss: 2.333793
# Epoch Average Loss: 2.325538
# Validate Acc: 0.100
# Epoch Average Loss: 2.324535
# Epoch Average Loss: 2.324206
# Epoch Average Loss: 2.320335
# Validate Acc: 0.100
# Epoch Average Loss: 2.327368
# Epoch Average Loss: 2.329508
# Epoch Average Loss: 2.333108
# Validate Acc: 0.100
# Epoch Average Loss: 2.330271
# Epoch Average Loss: 2.326144
# Epoch Average Loss: 2.327739
# Validate Acc: 0.100
# Epoch Average Loss: 2.332881
# Epoch Average Loss: 2.321262
# Epoch Average Loss: 2.327469
# Validate Acc: 0.116
# Epoch Average Loss: 2.324907
# Epoch Average Loss: 2.330634
# Epoch Average Loss: 2.323111
# Validate Acc: 0.100
# Epoch Average Loss: 2.327191
# Epoch Average Loss: 2.328566
# Epoch Average Loss: 2.326167
# Validate Acc: 0.100
# Epoch Average Loss: 2.323347
# Epoch Average Loss: 2.326230
# Epoch Average Loss: 2.325378
# Validate Acc: 0.100
# Epoch Average Loss: 2.328150
# Epoch Average Loss: 2.330224
# Epoch Average Loss: 2.327587
# Validate Acc: 0.132
# Epoch Average Loss: 2.324637
# Epoch Average Loss: 2.329604
# Epoch Average Loss: 2.326287
# Validate Acc: 0.100
# Epoch Average Loss: 2.328250
# Epoch Average Loss: 2.321238
# Epoch Average Loss: 2.326473
# Validate Acc: 0.132
# Epoch Average Loss: 2.323851
# Epoch Average Loss: 2.327055
# Epoch Average Loss: 2.325304
# Validate Acc: 0.116
# Epoch Average Loss: 2.325157
# Epoch Average Loss: 2.331042
# Epoch Average Loss: 2.327061
# Validate Acc: 0.132
# Epoch Average Loss: 2.329194
# Epoch Average Loss: 2.328621
# Epoch Average Loss: 2.325639
# Validate Acc: 0.100
# Epoch Average Loss: 2.330943
# Epoch Average Loss: 2.322837
# Epoch Average Loss: 2.326391
# Validate Acc: 0.132
# Epoch Average Loss: 2.328202
# Epoch Average Loss: 2.329454
# Epoch Average Loss: 2.321654
# Validate Acc: 0.132
# Epoch Average Loss: 2.328027
# Epoch Average Loss: 2.327280
# Epoch Average Loss: 2.331838
# Validate Acc: 0.132
# Epoch Average Loss: 2.330018
# Epoch Average Loss: 2.328084
# Epoch Average Loss: 2.329269
# Validate Acc: 0.132
# Epoch Average Loss: 2.325993
# Epoch Average Loss: 2.324532
# Epoch Average Loss: 2.329621
# Validate Acc: 0.100
# Epoch Average Loss: 2.325171
# Epoch Average Loss: 2.328110
# Epoch Average Loss: 2.328093
# Validate Acc: 0.132
# Epoch Average Loss: 2.325224
# Epoch Average Loss: 2.323039
# Epoch Average Loss: 2.335454
# Validate Acc: 0.116
# Epoch Average Loss: 2.329385
# Epoch Average Loss: 2.323622
# Epoch Average Loss: 2.331576
# Validate Acc: 0.100
# Epoch Average Loss: 2.329575
# Epoch Average Loss: 2.331687
# Epoch Average Loss: 2.320796
# Validate Acc: 0.132
# Epoch Average Loss: 2.330188
# Epoch Average Loss: 2.328148
# Epoch Average Loss: 2.325081
# Validate Acc: 0.116
# Epoch Average Loss: 2.322176
# Epoch Average Loss: 2.328423
# Epoch Average Loss: 2.324819
# Validate Acc: 0.132
# Epoch Average Loss: 2.327884
# Epoch Average Loss: 2.329892
# Epoch Average Loss: 2.324326
# Validate Acc: 0.100
# Epoch Average Loss: 2.327700
# Epoch Average Loss: 2.329309
# Epoch Average Loss: 2.329174
# Validate Acc: 0.100
# Epoch Average Loss: 2.325597
# Epoch Average Loss: 2.324508
# Epoch Average Loss: 2.324256
# Validate Acc: 0.132
# Epoch Average Loss: 2.327155
# Epoch Average Loss: 2.328622
# Epoch Average Loss: 2.327419
# Validate Acc: 0.132
# Epoch Average Loss: 2.323981
# Epoch Average Loss: 2.327670
# Epoch Average Loss: 2.326239
# Validate Acc: 0.100
# Epoch Average Loss: 2.336201
# Epoch Average Loss: 2.324293
# Epoch Average Loss: 2.326275
# Validate Acc: 0.132
# Epoch Average Loss: 2.321445
# Epoch Average Loss: 2.328080
# Epoch Average Loss: 2.332594
# Validate Acc: 0.100
# Epoch Average Loss: 2.328083
# Epoch Average Loss: 2.324913
# Epoch Average Loss: 2.323612
# Validate Acc: 0.116
# Epoch Average Loss: 2.328873
# Epoch Average Loss: 2.329805
# Epoch Average Loss: 2.328964
# Validate Acc: 0.100
# Epoch Average Loss: 2.322550
# Epoch Average Loss: 2.326481
# Epoch Average Loss: 2.331068
# Validate Acc: 0.100
# Validation accuracy:  0.1

# %%
# TODO: Plot the training_error and validation_accuracy of the best network (5%)
plt.subplot(2, 1, 1)
plt.plot(train_error)
plt.title("Training Loss History")
plt.xlabel("Iteration")
plt.ylabel("Loss")
# TODO: visualize the weights of the best network (5%)
plt.subplot(2, 1, 2)
plt.plot(validation_accuracy, label = 'val')
plt.title("Classification accuracy history")
plt.xlabel("Epoch")
plt.ylabel("Classification accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # Run on the test set (30%)
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 35%.

# %%
test_acc = (best_net_hyperparams.predict(x_test) == y_test).mean()
print("Test accuracy: ", test_acc)
# Out:
# Test accuracy:  0.144

# %% [markdown]
# #### Inline Question (10%)
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# #### Your Answer: 3
#
# #### Your Explanation: If the testing accuracy is much lower than the training accuracy, there exists overfitting. So we can increase the regulation strength to release the overfitting.
